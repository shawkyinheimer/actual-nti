# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('https://raw.githubusercontent.com/Rajvardhan180/House_Price_Prediction/main/data/Housing.csv')
data.columns = data.columns.str.strip().str.lower()
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
premium_data = data[
    (data['guestroom'] == 'yes') & 
    (data['airconditioning'] == 'yes') & 
    (data['area'] > 3000)
]

# %%
avg_price = premium_data.groupby('furnishingstatus')['price'].mean()
avg_bedrooms = premium_data.groupby('furnishingstatus')['bedrooms'].mean()
property_count = premium_data.groupby('furnishingstatus')['price'].count()

# %%
result = pd.DataFrame({
    'avg_price' : avg_price,
    'avg_bedrooms': avg_bedrooms,
    'property_count': property_count
})
result
# Out:
#                      avg_price  avg_bedrooms  property_count
# furnishingstatus
# furnished         7.039455e+06      3.545455              22
# semi-furnished    6.170231e+06      3.000000              13
# unfurnished       7.185938e+06      3.125000               8

# %%
data['energyload'] = (data['area']*0.5) + (data['bedrooms']*100) +  (data['bathrooms'] * 150)

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
filtereddf =  data[(data['hotwaterheating'] == 'yes') & (data['airconditioning'] == 'yes')]

# %%
filtereddf
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 378  3640000  2275         3          1        3      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 378             yes             yes        0      yes   semi-furnished
#
#      energyload
# 378      1587.5

# %%
avg_energyload = filtereddf.groupby('furnishingstatus')['energyload'].mean()
avg_price2 = filtereddf.groupby('furnishingstatus')['price'].mean()

# %%
result2 =  pd.DataFrame({
    'avg_energyload' : avg_energyload,
    'avg_price2': avg_price2,
})
result2
# Out:
#                   avg_energyload  avg_price2
# furnishingstatus
# semi-furnished            1587.5   3640000.0
